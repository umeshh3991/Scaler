# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_3/Module_3_Lec_8_Tuples_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = (1,2,3)
print(id(a))
b = (4,5)
                    ###tuple are concat but not append or extend

                    #### tuple after concat address change of a but not in case of list
a += b
print(a)
print(id(a))
# Out:
# 132257159043968
# (1, 2, 3, 4, 5)
# 132257577034000

# %%
a = [1,2,3]
print(id(a))
b = [4,5]

a += b
print(a)
print(id(a))
# Out:
# 132256588413696
# [1, 2, 3, 4, 5]
# 132256588413696

# %%
a = [1,2,3]
print(id(a))
b = [4,5]

a.extend(b)

print(a)
print(id(a))
# Out:
# 132256588402112
# [1, 2, 3, 4, 5]
# 132256588402112

# %%
a = [1,200,3000]
def foo(a):
  a[0] = 100
  print(id(a))

  print(a)        ### same value print x and a becoz of foo same function assigned both of us treat as x= a; list are mutable concept here


x = [1,2,3]


foo(x)
print(id(x))

print(x)
# Out:
# 132256590498944
# [100, 2, 3]
# 132256590498944
# [100, 2, 3]

# %%
a = [1,200,3000]
def foo(a):
  a[0] = 100

  print(a)        ### same value print x and a becoz of foo same function assigned both of us ttrat as x= a


x = [1,2,3]
x[0] = 29

foo(x)
x[0] = 56

print(x)
# Out:
# [100, 2, 3]
# [56, 2, 3]

# %%
a= {1,2,3,4,5,7,9}

print(type(a))
print(a)
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5, 7, 9}

# %%
a = {1,2,2,2,2,2,3}
print(a)
type(a)
# Out:
# {1, 2, 3}
# set

# %%
a = {9,2,5,7,9,4,1}
print(a)              ## not in ordered
# Out:
# {1, 2, 4, 5, 7, 9}

# %%
list({1,2,3,4,1,1,2,2,7,8})
# Out:
# [1, 2, 3, 4, 7, 8]

# %%
a = {1,2,3,4}
a.add(5)

# %%
a
# Out:
# {1, 2, 3, 4, 5}

# %%
a.clear()
a
# Out:
# set()

# %%
a = {1,1,1,2,3,4}
print(a)
len(a)
# Out:
# {1, 2, 3, 4}
# 4

# %%
a =('hello world')

print (tuple(a))

print (list(a))
print(set(a))
# Out:
# ('h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd')
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-69-1913992151.py in <cell line: 0>()
#       4
#       5 print (list(a))
# ----> 6 print(set(a))
#
# TypeError: 'set' object is not callable
