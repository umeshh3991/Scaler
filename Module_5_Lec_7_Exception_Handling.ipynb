# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Module_5/Module_5_Lec_7_Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exception Handling

# %%
ls
# Out:
# File1.py  sample_data/

# %%
f1 = open("File1.py", "r")
f1.read()
# Out:
# 'a = 10\n\ndef sum_numbers (num1) :\n  return num1 + a'

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1189138062.py in <cell line: 0>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
sum_numbers(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-870335359.py in <cell line: 0>()
# ----> 1 sum_numbers(20)
#
# NameError: name 'sum_numbers' is not defined

# %%
import File1

# %%
File1.a
# Out:
# 10

# %%
print(File1.sum_numbers(20))
# Out:
# 30

# %%
a = 30
print(File1.a)
print(a)
# Out:
# 10
# 30

# %%
File1.a = 40
print(File1.a)
# Out:
# 40

# %%
f1 = open("File1.py", "r")
f1.read()                      # still a = 10 in File1
# Out:
# 'a = 10\n\ndef sum_numbers (num1) :\n  return num1 + a'

# %% [markdown]
# In-Built Modules in Python

# %%
import math as mt

print(mt.pi)
# Out:
# 3.141592653589793

# %%
help(mt)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
help(File1)
# Out:
# Help on module File1:
#
# NAME
#     File1
#
# FUNCTIONS
#     sum_numbers(num1)
#
# DATA
#     a = 40
#
# FILE
#     /content/File1.py

# %%
mt.sqrt(90)
# Out:
# 9.486832980505138

# %%
import random as rd

rd.randint(0,100)
# Out:
# 20

# %%
help(rd)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
help(rd.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
list_1 = [1,2,3,4,5,99,55]

idx = rd.randint(0, len(list_1) - 1)
res = list_1[idx]

print(res)
# Out:
# 1

# %%
rd.seed(100)

# %%
print(rd.randint(0,10))
# Out:
# 6

# %%
for i in range (5) :
  print(rd.randint(0,10))
# Out:
# 1
# 1
# 7
# 4
# 0

# %%
rd.seed(20)

# %%
for i in range (7) :
  print(rd.randint(0,10))
# Out:
# 10
# 2
# 4
# 10
# 10
# 1
# 5

# %% [markdown]
#  After disconnecting reconnected again for below code to see how seed works

# %%
import random as rd

rd.seed(20)

for i in range (7) :
  print(rd.randint(0,10)) # This and above output will be same
# Out:
# 10
# 2
# 4
# 10
# 10
# 1
# 5

# %% [markdown]
# Various metchods of Importing

# %% [markdown]
# 1. Method 1

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(81)
# Out:
# 9.0

# %%
isinstance(math, object)
# Out:
# True

# %% [markdown]
# 2. Method 2

# %%
from math import *

pi
# Out:
# 3.141592653589793

# %%
sqrt(9)
# Out:
# 3.0

# %% [markdown]
# 3. Method 3

# %%
from math import pi as api

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
from math import sqrt as st, pi as p, floor as fl

# %% [markdown]
# Exception Handling

# %%
import thismodulenotexist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2398532301.py in <cell line: 0>()
# ----> 1 import thismodulenotexist
#
# ModuleNotFoundError: No module named 'thismodulenotexist'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
def division (a,b) :

  return(a/b)

#division(10,0)

# %%
try :
  division(10,0)

except :
  print("Some error happend")
# Out:
# Some error happend

# %%
try :
  print(division(10,20))

except :
  print("Some error happend")
# Out:
# 0.5
