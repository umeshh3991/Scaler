# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_2/Module_2_Lecture_2_Datatype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Type example

# %%
a=5
print(a)
print(type(a))
type(a)
# Out:
# 5
# <class 'int'>
# int

# %%
a=6.5
print(type(a))
# Out:
# <class 'float'>

# %%
b = 4+5j
print(type(b))
# Out:
# <class 'complex'>

# %%
umesh = "15"
print(type(umesh))
# Out:
# <class 'str'>

# %%
sapna = "4+5j"
print(type(sapna))
# Out:
# <class 'str'>

# %%
y = "sapna loves umesh"
print(y)
# Out:
# sapna loves umesh

# %% [markdown]
# WAP to find avg of 3 numbers

# %%
a = 7
b = 29
c = 36

avg = (a+b+c)/3

print (avg)
# Out:
# 24.0

# %% [markdown]
# RAM Concept

# %%
a = 7
b = a

print(id(b))
print(id(a))
# Out:
# 10751048
# 10751048

# %%
b = 6

print(id(b))
print(id(a))
# Out:
# 10751016
# 10751048

# %%
x = 6
y = 6

print(id(x))
print(id(y))
# Out:
# 10751016
# 10751016

# %%
def a1(x,y):
  sum = x + y
  print(sum)

a1(3,5)

a1(10,12)
# Out:
# 8
# 22

# %%
if_var = "sapna"
print(if_var)
print(id(if_var))
# Out:
# sapna
# 139249349691120

# %%
print(type(if_var))
# Out:
# <class 'str'>

# %% [markdown]
# HOMEWORK and ASSIGNMENTS
