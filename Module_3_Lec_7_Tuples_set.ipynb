# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_3/Module_3_Lec_7_Tuples_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = (1,2,3)
print(id(a))
b = (4,5)
                    ###tuple are concat but not append or extend

                    #### tuple after concat address change of a but not in case of list
a += b
print(a)
print(id(a))
# Out:
# 132257159043968
# (1, 2, 3, 4, 5)
# 132257577034000

# %%
a = [1,2,3]
print(id(a))
b = [4,5]

a += b
print(a)
print(id(a))
# Out:
# 132256588413696
# [1, 2, 3, 4, 5]
# 132256588413696

# %%
a = [1,2,3]
print(id(a))
b = [4,5]

a.extend(b)


print(a)
print(id(a))
# Out:
# 139190433744384
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1-1133060517.py in <cell line: 0>()
#       4
#       5 a.extend(b)
# ----> 6 a[1].replace(4)
#       7
#       8 print(a)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
a = [1,200,3000]
def foo(a):
  a[0] = 100
  print(id(a))

  print(a)        ### same value print x and a becoz of foo same function assigned both of us treat as x= a; list are mutable concept here


x = [1,2,3]


foo(x)
print(id(x))

print(x)
# Out:
# 132256590498944
# [100, 2, 3]
# 132256590498944
# [100, 2, 3]

# %%
a = [1,200,3000]
def foo(a):
  a[0] = 100

  print(a)        ### same value print x and a becoz of foo same function assigned both of us ttrat as x= a


x = [1,2,3]
x[0] = 29

foo(x)
x[0] = 56

print(x)
# Out:
# [100, 2, 3]
# [56, 2, 3]

# %%
a= {1,2,3,4,5,7,9}

print(type(a))
print(a)
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5, 7, 9}

# %%
a = {1,2,2,2,2,2,3}
print(a)
type(a)
# Out:
# {1, 2, 3}
# set

# %%
a = {9,2,5,7,9,4,1}
print(a)              ## not in ordered
# Out:
# {1, 2, 4, 5, 7, 9}

# %%
list({1,2,3,4,1,1,2,2,7,8})
# Out:
# [1, 2, 3, 4, 7, 8]

# %%
a = {1,2,3,4}
a.add(5)

# %%
a
# Out:
# {1, 2, 3, 4, 5}

# %%
a.clear()
a
# Out:
# set()

# %%
a = {1,1,1,2,3,4}
print(a)
len(a)
# Out:
# {1, 2, 3, 4}
# 4

# %%
a =('hello world')

print (tuple(a))

print (list(a))
print(set(a))
# Out:
# ('h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd')
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-69-1913992151.py in <cell line: 0>()
#       4
#       5 print (list(a))
# ----> 6 print(set(a))
#
# TypeError: 'set' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-3899789790.py in <cell line: 0>()
# ----> 1 A = A[0:9]
#
# NameError: name 'A' is not defined

# %%
print("hello +1+2+3")
# Out:
# hello +1+2+3

# %%
s ="MY PO Box number is 310"

print(s.isalnum())
print(s.isspace())
# Out:
# False
# False

# %%
s ="hello"
print(s[::-1])
print(s[0:9])
print(s[9])
# Out:
# olleh
# hello
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-18-2008877491.py in <cell line: 0>()
#       2 print(s[::-1])
#       3 print(s[0:9])
# ----> 4 print(s[9])
#
# IndexError: string index out of range

# %%
a = "1,2,3,4 "

a.split{"/"}
# Out:
#   File "/tmp/ipython-input-97-1038317152.py", line 3
#     a.split{"/"}
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1.Problem Description
#
# You are given a character string A, having length N and an integer ASCII code B.
#
#
# You have to tell the leftmost occurrence of the character having ASCII code equal to B, in A or report that it does not exist.
#
#
#
#                                                 image
#
#
#
#
#
# Problem Constraints
#
# 1 <= N <= 105
#
#
#
#
# A[i] ∈ ['a'-'z']
#
# 97 <= B <= 122
#
#
#
#
#
#
# Input Format
#
# First argument is a character string A.
#
#
#
#
# Second argument is an integer B.
#
#
#
#
#
#
# Output Format
#
# If there exists an occurrence, return the leftmost index(0 - based), else return -1.
#
#
#
# Example Input
#
# Input 1:
#
#
#
#
#  A = "aabbcc"
#  B = 98
# Input 2:
#
#  A = "abc"
#  B = 100
#
#
#
#
#
# Example Output
#
# Output 1:
#
#
#
#
#  2
# Output 2:
#
#  -1
#
#
#
#
#
# Example Explanation
#
# Explanation 1:
#
#
#
#
#  Character having ASCII code equal to 98 = 'b'
#  Leftmost index of character 'b' in "aabbcc" is 2.
# Explanation 2:
#
#  Character having ASCII code equal to 100 = 'd'
#  Character 'd' is not present in "abc".

# %%
def leftmost_occurance_char(char,digit):



  for i in range (len(char)):

    if digit == ord(char[i]):

      return(i)

  return(-1)

# %%
string_char =input("Enter the char : ")

number =int(input("Enter the digit number : "))

output = leftmost_occurance_char(string_char,number)

print(output)
# Out:
# Enter the char : aabbcc
# Enter the digit number : 98
# 2

# %% [markdown]
# You have a string (A).
#
# You have to return length of input string.
#
#
#
# Problem Constraints
#
# 1 <= A.size() <= 1000
#
#
#
# Input Format
#
# First and only argument containing a lowercase string A.
#
#
#
# Output Format
#
# You have to return an integer as per the question.
#
#
#
# Example Input
#
# Input 1:
#
# scaler
# Input 2:
#
# interviewbit
#
#
# Example Output
#
# Output 1:
#
# 6
# Output 2:
#
# 12
#
#
# Example Explanation
#
# Explanation 1:
#
# Clearly,  length of scaler is 6.
# Explanation 2:
#
# Clearly, length of interviewbit is 12.

# %%
def length_string(char):

  count = 0

  for i in  range(len(char)):

    count = count+1

  return(count)

# %%
string_char =input("Enter the char : ")

output = length_string(string_char)

print(output)
# Out:
# Enter the char : interviewbit
# 12

# %% [markdown]
# Problem Description
#
# You are given a character string A and two integer ASCII codes B and C.
#
# You have to find and replace all the occurrences of the character having ASCII code equal to B with character having ASCII code equal to C and return the resultant string.
#
#                                                 image
#
#
# Problem Constraints
#
# 1 <= N <= 105
#
# A[i] ∈ ['a'-'z']
#
# 97 <= B, C <= 122
#
#
#
# Input Format
#
# First argument is a character string A.
#
# Second argument is an integer B.
#
# Third argument is an integer C.
#
#
#
# Output Format
#
# Return the resultant string after replacing the character(s).
#
#
#
# Example Input
#
# Input 1:
#
#  A = "aabbccbb"
#  B = 98
#  C = 100
# Input 2:
#
#  A = "abc"
#  B = 100
#  C = 97
#
#
# Example Output
#
# Output 1:
#
#  aaddccdd
# Output 2:
#
#  abc

# %%
def resultant_string(char,int_A,int_B):



  x =chr(int_B)

  for i in range (len(char)):

      if int_A == ord(char[i]):

        char = char.replace(char[i],x)

        return(char)

  return(char)

# %%
string_char =input("Enter the char : ")

number_1 =int(input("Enter the digit number : "))

number_2 =int(input("Enter the digit number : "))

output = resultant_string(string_char,number_1,number_2)

print(output)
# Out:
# Enter the char : aabbc
# Enter the digit number : 100
# Enter the digit number : 97
# aabbc

# %%
chr(100)
# Out:
# 'd'

# %%
x =chr(100)
print(x)

y =[1,2,3]

y[0] = 4
print(y)
# Out:
# d
# [4, 2, 3]

# %% [markdown]
# 4.Problem Description:
#
# Given the input date in DD/MM/YYYY format as a string, write a function that returns the converted date in the string formats MM/DD/YYYY and YYYY/MM/DD and return the new date formats.
#
# Input Format:
#
# First input line will have the number of test cases. There will be a single line of input for each
# testcase which will consist of date in the string format DD/MM/YYYY.
# Output Format:
#
# Resultant date formats in string formats MM/DD/YYYY and YYYY/MM/DD
# Sample Input:
#
# 1
# "08/12/1998"
# Sample Output:
#
# 12/08/1998
# 1998/12/08

# %%
def date_format(input_date):

  date,month,year = input_date.split("/")

  return(f"{month}/ {date}/ {year}", f"{year}/ {month}/ {date}")

# %%
update_date = input("Enter string date format we require : ")

result_update_format = date_format(update_date)

print(result_update_format)
# Out:
# Enter string date format we require : 12/09/2100
# ('09/ 12/ 2100', '2100/ 09/ 12')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-132-3360277643.py in <cell line: 0>()
# ----> 1 date1= (input("Enter the date1 : "))
#       2 #mo = (input("Enter the month : "))
#       3 #yr  = (input("Enter the year : "))
#       4
#       5 y = date_format("date1")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Problem Description:
#
# Write a function to search for a given element elem in the tuple tup and return its index. Return -1 if elem is not present in tup.
#
# Input Format:
#
# The first line consists of tuple.
# The second line consists of an element for which index is required to be returned.
# Output Format:
#
# Return the index value in integer format.
# Sample Input:
#
# (10, 20, 30, 40, 50)
# 30
# Sample Output:
#
# 2
# Sample explanation:
#
# 30 is present at index 2, therefore 2 is returned.

# %%
def search_element_pos(input_element, elem):

  for i in range (len(input_element)):
    if elem == input_element[i]:


      return(i)

# %%
total_element = []

total_number = int(input("Enter number of element : "))
position_value = int(input("Enter position value : "))

for i in range (total_number):

  element = int(input("Enter element : "))

  total_element.append(element)

A = tuple(total_element)
print(A)

result = search_element_pos(A,position_value)

print(result)
# Out:
# Enter number of element : 4
# Enter position value : 10
# Enter element : 10
# Enter element : 20
# Enter element : 30
# Enter element : 40
# (10, 20, 30, 40)
# 0

# %% [markdown]
# Problem Description:
#
# Write a program to divide a given tuple into two tuples that contain even and odd indexed elements of the original tuple. Print both these tuples in the given output format.
#
# Note: The input tuple follows 1-based indexing. This means the element at index 0 is treated as having index as 1.
#
# For example, (9,2,3). The 1-based index of 2 is 2.
#
# Input Format:
#
# The input contains a tuple as an argument to the function.
# Output Format:
#
# Print two tuples one for odd indexed elements and another for even indexed elements in the following format:
# Odd: (....)
# Even: (....)
# Sample Input:
#
# 1
# (10, 8, 5, 2, 10, 15, 10, 8, 5, 8, 8, 2)
# Sample Output:
#
# Odd: (10, 5, 10, 10, 5, 8)
# Even: (8, 2, 15, 8, 8, 2)

# %%
def indexed_even_odd(input_element):

  even_el = []
  odd_el = []
  #even_element = 0
  #odd_element = 0


  for i in range (len(input_element)):


    if i % 2 == 0:
      odd_element = 0

      odd_element += input_element[i]
      odd_el.append(odd_element)

    else:

      even_element = 0

      even_element += input_element[i]
      even_el.append(even_element)

  A_odd = tuple(odd_el)
  A_even = tuple(even_el)
  return(A_odd,A_even)

# %%
total_element = []

total_number = int(input("Enter number of element : "))

for i in range (total_number):

  element = int(input("Enter element : "))

  total_element.append(element)

B = tuple(total_element)
print()

result  = indexed_even_odd(B)

print(result)
# Out:
# Enter number of element : 6
# Enter element : 1
# Enter element : 2
# Enter element : 3
# Enter element : 4
# Enter element : 5
# Enter element : 6
# (1, 2, 3, 4, 5, 6)
# ((1, 3, 5), (2, 4, 6))

# %% [markdown]
# Problem Description:
#
# Write a function to print out the frequency of all the unique elements present in a given tuple.
#
# Input Format:
#
# The one input line consists of a tuple.
# Output Format:
#
# Unique elements and their frequencies are expected to be printed as follows:
# unique_element1 : freq1
# unique_element2 : freq2
# .
# .
# Sample Input 1:
#
# (10, 8, 5, 2, 10, 15, 10, 8, 5, 8, 8, 2)
# Sample Output 1:
#
# 10 : 3
# 8 : 4
# 5 : 2
# 2 : 2
# 15 : 1
# Sample Input 2:
#
# (100, -10, -10, “ONE”, [22], [22], “ONE”)
# Sample Output 2:
#
# 100 : 1
# -10 : 2
# ONE : 2
# [22] : 2

# %%
def search_element_pos(input_element):

  count = 0

  for i in range (len(input_element)):

    for j in (i):


      if i[j] == i[j+1]:


        count += 1

    A = tuple(count)

    print(A)

# %%
total_element = []

total_number = int(input("Enter number of element : "))

for i in range (total_number):

  element = int(input("Enter element : "))

  total_element.append(element)

B = tuple(total_element)
print()

result  = search_element_pos(B)

print(result)
# Out:
# Enter number of element : 4
# Enter element : 1
# Enter element : 1
# Enter element : 2
# Enter element : 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-37-3609076949.py in <cell line: 0>()
#      12 print()
#      13
# ---> 14 result  = search_element_pos(B)
#      15
#      16 print(result)
#
# /tmp/ipython-input-36-3623266309.py in search_element_pos(input_element)
#       5   for i in range (len(input_element)):
#       6
# ----> 7     for j in (i):
#       8
#       9
#
# TypeError: 'int' object is not iterable

# %%
A = [1,1,1,1,2,3,3,4]


B = set(A)
c =list(B)


print(c)





for i in range (len(A)):
  if A[i] == c[0]:
    count = 1


    count += 1
print(count)
# Out:
# 1
# [1, 2, 3, 4]
# 2

# %% [markdown]
# Problem Description:
#
# Given two sentences, write a program to return the sum of the total number of unique words from each sentence.
#
# Input Format:
#
# The first line indicates the number of test cases.There will be two lines of inputs for each test cases as following:
# The two lines consist of two sentences in string format.
# Output Format:
#
# The number of unique words from the sentences in integer format.
# Sample Input:
#
# 1
# in data analysis we use data and process it further to create better interpreted data
# more and more data will be passively collected
# Sample Output:
#
# 20
# Sample explanation:
#
# {'use', 'process', 'create', 'better', 'analysis', 'in', 'it', 'further', 'and', 'we', 'data', 'interpreted', 'to'}
# represent the 13 unique words from sentence1 and {'collected', 'more', 'be', 'and', 'data', 'passively', 'will'}
# represent the 7 unique words from sentence2. Therefore 13 + 7 = 20 is returned.
# Note:
#
# If a word is present in both sentences it should be counted separately for both sentences.

# %%
def count(sent1,sent2):
  count =1

  for i in range (len(sent1)):

    count += 1


  print(count)

# %%
sentence_1 = input("Enter words of sentences :")

sentence_2 = input("Enter words of sentences : ")

result = count(sentence_1,sentence_2)
print(result)
# Out:
# Enter words of sentences :"hi" ,"hey" ,"hello"
# Enter words of sentences : "ram"
# 21
# None
