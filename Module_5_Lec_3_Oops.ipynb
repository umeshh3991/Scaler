# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Module_5/Module_5_Lec_3_Oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Dog :

  breed = "Shitzu"
  name = "Togo"

  def intro(self) :
    print(f"Hello my name is  {self.name} bhau bhau")

# %%
d1 = Dog ()
print(d1.breed)
# Out:
# Shitzu

# %%
d2 = Dog()
print(d1.breed)
print(d2.breed)
# Out:
# Shitzu
# Shitzu

# %%
d2.breed = "Pitbull"

print(d1.breed)
print(d2.breed)
# Out:
# Shitzu
# Pitbull
