# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_3/Module_3_Lec_6_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# string comparison

# %%
"abc" > "ABC"
# Out:
# True

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
print("abc\b")       ##\b remove last element
# Out:
# abc

# %%
a = """adsfdgdthfykmfjhd"""
type(a)
# Out:
# str

# %%
a ='''sdskfjsogkdhokoerkale'''
type(a)
# Out:
# str

# %%
a =  """........
dokgpofdhkspoksokspo"""

type(a)
# Out:
# str

# %%
def remove(s,i):

  ##want to remove ith char remove from elements

    return(s[:i] + s[i+1:])

# %%
 remove("umesh",3)
# Out:
# 'umeh'

# %% [markdown]
# operation on a string
#
# concatenation

# %%
a = "hello" + "world"

print(a)
# Out:
# helloworld

# %%
a = "hello" "world"
                                 ##no need to plus for concat
print(a)
# Out:
# helloworld

# %% [markdown]
# iteration

# %%
a =" umesh"

for char in a:
  print(char)
# Out:
#
# u
# m
# e
# s
# h

# %%
s = "umesh"
list(s)
# Out:
# ['u', 'm', 'e', 's', 'h']

# %% [markdown]
# method in string

# %%
"umesh".upper()
# Out:
# 'UMESH'

# %%
"UMesh".lower()
# Out:
# 'umesh'

# %%
"umesh".islower()
# Out:
# True

# %%
"es" in "umesh"
# Out:
# True

# %%
"umesh".title()
# Out:
# 'Umesh'

# %% [markdown]
# string interpolation

# %%
a = 3
b = 4
"a+ b = {}".format(a+b)
# Out:
# 'a+ b = 7'

# %%
"a ={}, b = {}, a+b = {}".format(a,b,a+b)
# Out:
# 'a =3, b = 4, a+b = 7'

# %% [markdown]
# keyword argument

# %%
"hello my name is {name} and work at {company}".format(name = "umesh", company = "abc")
# Out:
# 'hello my name is umesh and work at abc'

# %%
for student in students:

  print("hello {name}  you scored {score} in python" .format(name =student["name"],score = student["score"]))
# Out:
# hello asfs   you scored 12 in python
# hello  dada  you scored 21 in python
# hello  sdsf  you scored 2113 in python
# hello dfs   you scored 213 in python
# hello cvv   you scored 232 in python

# %% [markdown]
# string modifier

# %%
print(len("\\\\\\"))
# Out:
# 3

# %%
print("\\\\\\")
# Out:
# \\\

# %% [markdown]
# raw string

# %%
a = r"fdgfg\t\nee\\\\"
print(a)
print(len(a))
# Out:
# fdgfg\t\nee\\\\
# 15

# %% [markdown]
# format string modifier

# %%
for student in students:

  print(
      f"hello {student['name']}  you scored {student['score']} in python"
      )
# Out:
# hello asfs   you scored 12 in python
# hello  dada  you scored 21 in python
# hello  sdsf  you scored 2113 in python
# hello dfs   you scored 213 in python
# hello cvv   you scored 232 in python

# %%
print("a\\b")
# Out:
# a\b

# %%
print("a//b")
# Out:
# a//b

# %% [markdown]
# 1.Problem Description
#
# You are given lowercase string (S) and you have to return a string that is the uppercase form of S.
#
#
# Problem Constraints
#
# 1 <= S.size() <= 1000
#
#
#
# Input Format
#
# First and only argument containing a lowercase string S.
#
#
#
# Output Format
#
# You have to return uppercase form of input string.
#
#
#
# Example Input
#
# Input 1:
#
# interviewbit
# Input 2:
#
# scaler
#
#
# Example Output
#
# Output 1:
#
# INTERVIEWBIT
# Output 2:
#
# SCALER

# %%
def convert_uppercase_string(lowercase_string):

  return(lowercase_string.upper())

# %%
string_upper = input("Enter name of string : ")

output = convert_uppercase_string(string_upper)
print(output)
# Out:
# Enter name of string : fgdfhgjh
# FGDFHGJH

# %% [markdown]
# 2.Problem Description
#
# You are given uppercase string (S) and you have to return a string that is the lower case form of S.
#
# Uppercase strings are those which have all letters in uppercase (Example: MACHINE)
#
# Lowercase strings are those which have all letters in lowercase (Example: machine)
#
# Problem Constraints
#
# 1 <= S.size() <= 1000
# Input Format
#
# First and only argument containing a uppercase string **S**.
# Output Format
#
# You have to return lowercase form of input string.
# Example Input
#
# Input 1:
# INTERVIEWBIT
# Input 2:
# SCALER
# Example Output
#
# Output 1:
# interviewbit
# Output 2:

# %%
def convert_lowercase_string(uppercase_string):

  return(uppercase_string.lower())

# %%
string_lower = input("Enter name of string : ")

output = convert_lowercase_string(string_lower)
print(output)
# Out:
# Enter name of string : DFGFDSHYDFHD
# dfgfdshydfhd

# %% [markdown]
# Problem Description
#
# You are given lowercase string (A) and you have to tell the count of vowels and consonants in it.
#
#
#
# Problem Constraints
#
# 1 <= A.size() <= 1000
#
#
#
# Input Format
#
# First and only argument containing a lowercase string A.
#
#
#
# Output Format
#
# You have to return an array of two elements representing count of vowels and consonants in the input string respectively.
#
#
#
# Example Input
#
# Input 1:
#
# interviewbit
# Input 2:
#
# scaler
#
#
# Example Output
#
# Output 1:
#
# [5 7]
# Output 2:
#
# [2 4]
#
#
# Example Explanation
#
# Explanation 1:
#
# Clearly, interviewbit has 4 vowels and 7 consonants.
# Explanation 2:
#
# Clearly, scaler has 2 vowels and 4 consonants.

# %%
def count_vowel_consonants(lowercase_string):

  count_vowel = 0
  count_consonants = 0

  for j in lowercase_string:

     if (j == "a" or j =="e" or j == "i" or j == "o" or j == "u"):

      count_vowel = count_vowel + 1

     else:

      count_consonants += 1

  #print(count_vowel)
  return(count_vowel,count_consonants)

# %%
string_low = input("Enter name of  string : ")


output =  count_vowel_consonants(string_low)

print(output)
# Out:
# Enter name of  string : scaler
# (2, 4)

# %% [markdown]
# Use Hint
# Problem Description
#
# You are given lowercase string (A) and you have to return after reversing that.
#
#
# Problem Constraints
#
# 1 <= S.size() <= 1000
#
#
# Input Format
#
# First and only argument containing a lowercase string S.
#
#
#
# Output Format
#
# You have to return string which is reverse form of input string.
#
#
#
# Example Input
#
# Input 1:
#
# interviewbit
# Input 2:
#
# scaler
#
#
# Example Output
#
# Output 1:
#
# tibweivretni
# Output 2:
#
# relacs

# %%
def reverse_string(lowercase_string):

  for i in lowercase_string:

    output_string = lowercase_string[::-1]

  return(output_string)

# %%
string_low = input("Enter name of  string : ")


output =  reverse_string(string_low)

print(output)
# Out:
# Enter name of  string : scaler
# relacs

# %% [markdown]
# 5.Problem Description:
#
# Write a program to return a string from a given string s where all occurrences of
# the first char of the string except the first occurrence have been changed to '$'.
# Input Format:
#
# The number of test cases. For each testcase there will be a single line of input as explained following.
# The single line consists of a string.
# Output Format:
#
# Resultant string
# Sample Input:
#
# 1
# "restart"
# Sample Output:
#
# "resta$t"
# Sample Explanation:
#
# ‘r’ is the first character of the string. We have to replace all the occurrences of r to ‘$’
#  except the one at index 0.

# %%
def replace_char(string_convert):

  char = string_convert[0]

  string_convert = string_convert.replace(char,"$")

  output = char + string_convert[1:]

  return(output)

# %%
String_name =input("Enter name of string : ")

output = replace_char(String_name)

print(output)
# Out:
# Enter name of string : scasers
# sca$er$

# %% [markdown]
# Problem Description:
#
# Write a program that takes a sentence as a parameter and returns the number of alphabets and digits separately.
#
# Input Format:
#
# First line will have the number of test cases. For each testcase there will be one line of input consisting
# of string/sentence in string format.
# Output Format:
#
# Count of alphabets and digits in the given string.
# Sample Input:
#
# 1
# John.Smith1990@gmail.com
# Sample Output:
#
# Number of alphabets:  17
# Number of Digits:  4
# Sample explanation:
#
# The four digits are 1,9,9, and 0. The 17 alphabets are J,o,h,n,S,m,i,t,h,g,m,a,i,l,c,o and m.

# %%
def count_parameter(string_alpha_digit):

  count_alpha = 0
  count_digit = 0


  for i in  (string_alpha_digit):

    if (i == "0" or  i == "1" or  i == "2" or  i == "3" or  i == "4" or  i == "5" or  i == "6" or  i == "7" or  i == "8" or  i == "9"):

      count_digit = count_digit + 1


    else:

      count_alpha = count_alpha + 1

  return(count_digit,count_alpha)

# %%
string_name = input("Enter name of string : ")

output = count_parameter(string_name)

print(output)
# Out:
# Enter name of string : sddfsg@1234
# (4, 7)

# %% [markdown]
# 7.Problem Description:
#
# Write a program to check whether two given strings are anagrams or not. Return True if the strings are anagrams else return False.
#
# Note: An anagram of a string is another string that contains the same characters, only the order of characters can be different.
#
# Input Format:
#
# The first line of input contains the number of test cases.
# The next 2t lines contain two strings a and b for which you need to check if they are an anagram.
# You are given a function where the two arguments to the function are strings a and b.
# Output Format:
#
# True or False
# Sample Input 1:
#
# 1
# Hello
# Hi
# Sample Output 1:
#
# False
# Sample explanation:
#
# 'Hello' and 'Hi' have only just one same character 'H' therefore False is returned.
# Sample Input 2:
#
# 1
# listen
# silent
# Sample Output 2:
#
# True
# Sample explanation:
#
# 'silent' and 'listen' have all the same characters with same frequency but in different order therefore True is returned.

# %%
def anagrams(str1,str2):

  sort_str1 = sorted(str1)

  sort_str2 = sorted(str2)

  if sort_str1[::] != sort_str2[::]:
    return("false")

  return("true")

# %%
string_name1 = input("Enter name of string : ")
string_name2 = input("Enter name of string : ")

res_output = anagrams(string_name1,string_name2)

print(res_output)
# Out:
# Enter name of string : level
# Enter name of string : evell
# true

# %% [markdown]
# Problem Description:
#
# Write a program to check whether the given string is a palindrome or not. Return True if it is palindrome else return False.
#
# Note: A string is said to be a palindrome if the reverse of the string is the same as the string itself.
#
# Input Format:
#
# First line will have the number of test cases. For each testcase there will be single line of input consisting of a string.
# Output Format:
#
# True if palindrome else False
# Sample Input 1:
#
# 1
# level
# Sample Output 1:
#
# True
# Sample explanation:
#
# 'level' when reversed returns 'level' only which are same therefore True is returned.
# Sample Input 2:
#
# 1
# Scaler
# Sample Output 2:
#
# False
# Sample explanation:
#
# 'Scaler' when reversed returns 'relacS' which is not equal to original string therefore False is returned.

# %%
def palindrome(string):

  if string[0::] == string[::-1]:

     return("true")



  return("false")

# %%
string_name = input("Enter name of string : ")

output = palindrome(string_name)

print(output)
# Out:
# Enter name of string : saspsd
# false
