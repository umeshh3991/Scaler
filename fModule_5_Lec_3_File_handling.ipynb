# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_5/fModule_5_Lec_3_File_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
open("new_file.txt",'r')
# Out:
# <_io.TextIOWrapper name='new_file.txt' mode='r' encoding='utf-8'>

# %%
open("new_file.txt",'w')
# Out:
# <_io.TextIOWrapper name='new_file.txt' mode='w' encoding='utf-8'>

# %%
f =open("new_file.txt",'w')

# %%
f.write("hello world")
# Out:
# 11

# %%
f = open("new_file.txt",'r')

# %%
f.close()

# %%
f.read()
# Out:
# 'hello worldhello worldhello world'

# %%
f.read(3)
# Out:
# 'wor'

# %%
f.read(12)
# Out:
# 'o worldhello'

# %%
f.read(14)
# Out:
# ' world'

# %%
f.seek(0)        #rest the value, after cursur goes to pos 0
# Out:
# 0

# %%
f.read()
# Out:
# 'hello worldhello worldhello world'

# %%
f.seek(3)
# Out:
# 3

# %%
f.read()
# Out:
# 'lo worldhello worldhello world'

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3059900045.py in <cell line: 0>()
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f = open("new_file3.txt",'w+')

# %%
f.write("Bye")
# Out:
# 3

# %%
f.close()

# %%
f = open("new_file3.txt",'r')

# %%
f.read()         ##append bye
# Out:
# 'Bye'

# %%
f = open("new_file.txt",'w+')   ##due to w+ all previous record are deleted or not existed

# %%
f.read()
# Out:
# ''

# %%
f = open("new_file2.txt",'a')

# %%
f.write("hi")
# Out:
# 2

# %%
f = open("new_file2.txt",'r')

# %%
f.read()
# Out:
# 'hihihihihi'

# %%
f.close()

# %%
file = open("sample_data/ california_housing_train.txt",'w')
file. write("sample_data/ california_housing_train.txt")
# Out:
# 41

# %%
file = open("sample_data/ california_housing_train.csv",'r')

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# new_file2.txt  new_file3.txt  new_file.txt  sample_data/

# %%
ls sample_data
# Out:
#  anscombe.json*                  ' california_housing_train.txt'
#  california_housing_test.csv      mnist_test.csv
# ' california_housing_train.csv'   mnist_train_small.csv
#  california_housing_train.csv     README.md*

# %%
file = open("sample_data/ california_housing_train.csv",'r')
file.readline()
# Out:
# ''

# %%
file =open("my new file.txt",'w+')
file.writelines(("this is line1\n", "this is line2\n", "this is line3\n"))
file.close()

# %%
file =open("my new file.txt",'r')
file.readline()
# Out:
# 'this is line1\n'

# %%
file.readline()
# Out:
# 'this is line2\n'

# %%
file.readline()
# Out:
# 'this is line3\n'

# %%
file.readline()
# Out:
# ''

# %%
f.close()

# %%
file =open("my new file.txt",'w+')
file.writelines(("this is line1\n", "this is line2\n", "this is line3\n"))
file.close()
                                                                              ## readlines print single line o/p
file =open("my new file.txt",'r')
file.readlines()
# Out:
# ['this is line1\n', 'this is line2\n', 'this is line3\n']

# %%
file =open("my new file.txt",'w+')
file.writelines(("this is line1", "this is line2", "this is line3"))
file.close()
                                                                                    ###if remove \n
file =open("my new file.txt",'r')
file.readlines()
# Out:
# ['this is line1this is line2this is line3']

# %%
file =open("my new file.txt",'r')
a =file.readline()

while a != "":
  print(a)
  a =file.readline()
# Out:
# this is line1
#
# this is line2
#
# this is line3

# %%
with open ("my new file.txt",'r')as file:
  print(file.read(5))                         ############### with open...as file that closed file
# Out:
# this

# %%
file.read(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-453166932.py in <cell line: 0>()
# ----> 1 file.read(10)
#
# ValueError: I/O operation on closed file.

# %%
f3=open("new_file5.txt",'w')
f3.write("hello world")
# Out:
# 11

# %%
f3.write("hiiii")
# Out:
# 5

# %%
f3.close()

# %%
f3=open("new_file5.txt",'r')
f3.read()
# Out:
# 'hello worldhiiii'

# %%
f4=open("new_file5.txt",'a')
f4.write("fgdf")
# Out:
# 4

# %%
f4.close()

# %%
f4=open("new_file5.txt",'r')
f4.read()
# Out:
# 'fgdffgdf'

# %%
with open("essay.txt","w") as f:
  f.write("hrty")
  f.close()

# %%
with open("essay.txt","r") as f:

    count = 0

    data = f.read

    words = data.split()

    for word in words:

        count += 1

    print(count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3867655544.py in <cell line: 0>()
#       5     data = f.read
#       6
# ----> 7     words = data.split()
#       8
#       9     for word in words:
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'split'

# %%
f.close()

# %%
file12 =open("my new file.txt",'w')
file12.write("this is line1\n")
file12.close()
                                                                              ## readlines print single line o/p
file12 =open("my new file.txt",'r')
file12.read()
# Out:
# 'this is line1\n'

# %%
file =open("my new file.txt",'w+')
file.writelines("this is line1\n", "this is line2\n", "this is line3\n")
file.close()
                                                                              ## readlines print single line o/p
file =open("my new file.txt",'r')
file.readlines()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3469509192.py in <cell line: 0>()
#       1 file =open("my new file.txt",'w+')
# ----> 2 file.writelines("this is line1\n", "this is line2\n", "this is line3\n")
#       3 file.close()
#       4                                                                               ## readlines print single line o/p
#       5 file =open("my new file.txt",'r')
#
# TypeError: _IOBase.writelines() takes exactly one argument (3 given)

# %%
file =open("my new file.txt",'w+')
file.writelines("this is line1\n", "this is line2\n", "this is line3\n")
file.close()
                                                                              ## readlines print single line o/p
file =open("my new file.txt",'r')
file.readlines()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3469509192.py in <cell line: 0>()
#       1 file =open("my new file.txt",'w+')
# ----> 2 file.writelines("this is line1\n", "this is line2\n", "this is line3\n")
#       3 file.close()
#       4                                                                               ## readlines print single line o/p
#       5 file =open("my new file.txt",'r')
#
# TypeError: _IOBase.writelines() takes exactly one argument (3 given)

# %%
f = None
for i in range (5):
    with open("data.txt", "w") as f:
        if i > 2:
            break
print(f.closed)
# Out:
# True
