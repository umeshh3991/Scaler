# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_2/Module_3_lec_1_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Hello():

  print(" Hello world")

# %%
Hello()
# Out:
#  Hello world

# %%
def add(a,b):
  print(a + b)

# %%
add(3,4)
# Out:
# 7

# %%
def subtract(a,b):
  print(a - b)

# %%
subtract(4,8)
# Out:
# -4

# %%
def add(a,b):
  print(a + b)
  return a+b

# %%
x = add (1,4)
# Out:
# 5

# %%
print(x)
# Out:
# None
