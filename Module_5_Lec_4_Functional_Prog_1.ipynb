# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Module_5/Module_5_Lec_4_Functional_Prog_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class A :
  counter = 0

  def __init__(self) :
    self.counter += 1
    print("New object Created")

A()  # 1st OBJECT CREATED

obj1 = A()  # 2nd OBJECT CREATED

if A() :    # 3rd OBJECT CREATED
  print(A())  # 4th OBJECT CREATED
# Out:
# New object Created
# New object Created
# New object Created
# New object Created
# ...

# %%
class A :
  counter = 0

  def __init__(self) :
    A.counter += 1

A()

obj1 = A()

if A():
  print (A.counter)
# Out:
# 2
# 3

# %%
class A :
  counter = 0

  def __init__(self) :
    self.counter += 1

A()

obj1 = A()

if A():
  print (A.counter)
# Out:
# 0
# 0

# %%
class A :

  counter = []

  def __init__(self) :
    self.counter.append(1)

A()

obj1 = A()

if A():
  print (A.counter)
# Out:
# [1, 1, 1]

# %%
class A :

  counter = "Umesh"

  def __init__(self) :
    self.counter = "Sapna"

A()

obj1 = A()

if A():
  print (A.counter)
# Out:
# Umesh

# %% [markdown]
# **Functional Programming**

# %% [markdown]
# 1. Lambda Function

# %%
def square (x) :
  return(x ** 2)

# %%
square(3)
# Out:
# 9

# %%
a = 3
(lambda x : x ** 2)(a) # anonymous function
# Out:
# 9

# %%
z = (lambda x : x ** 2)

# %%
z(10)
# Out:
# 100

# %% [markdown]
# 2. If else Lambda ()

# %%
la_1 = (lambda x : x if x > 5 else x+10)

# %%
la_1(3)
# Out:
# 13

# %% [markdown]
# 3. Elif condition in lambda

# %%
la_2 = (lambda x : x if x < 5 else (x + 10) if x < 10 else (x+20))

# %%
la_2(6)
# Out:
# 16

# %% [markdown]
# 4. Multiple Arguments Using Lambda

# %%
la_3 = (lambda x,y : x+y)

# %%
la_3(2,3)
# Out:
# 5

# %%
la_4 = (lambda x,y : (x * y , x / y ))

# %%
la_4(4,2)
# Out:
# (8, 2.0)

# %% [markdown]
# 5. Lambda Function Applications

# %%
list_1 = [[11,91,3],
          [3,4,5],
          [56,89,90]]

# %%
sorted(list_1, key = lambda x:x[1])
# Out:
# [[3, 4, 5], [56, 89, 90], [11, 91, 3]]

# %%
dict1 = {"A":30,
         "V":20,
         "C":10,
         "D":50,
         "E":40
         }

# %%
sorted(list(dict1.items()))
# Out:
# [('A', 30), ('C', 10), ('D', 50), ('E', 40), ('V', 20)]

# %%
sorted(list(dict1.items()), key = lambda x : x[1])
# Out:
# [('C', 10), ('V', 20), ('A', 30), ('E', 40), ('D', 50)]

# %%
output_dict = dict(sorted(list(dict1.items()), key = lambda x : x[1], reverse = True))

# %%
print(output_dict)
# Out:
# {'D': 50, 'E': 40, 'A': 30, 'V': 20, 'C': 10}

# %%
student = [
    {"name" : "Umesh", "marks" : 80},
    {"name" : "Sapna", "marks" : 78},
    {"name" : "Vijay", "marks" : 60},
    {"name" : "Praful", "marks" : 90}
]

# %%
sorted(student, key = lambda x : x["marks"], reverse=True)
# Out:
# [{'name': 'Praful', 'marks': 90},
#  {'name': 'Umesh', 'marks': 80},
#  {'name': 'Sapna', 'marks': 78},
#  {'name': 'Vijay', 'marks': 60}]

# %% [markdown]
# **Higher Order Function**

# %%
def hots () :
  def print_hello () :
    print("Hello World")

  return (print_hello)

# %%
a = hots()
print(a)
# Out:
# <function hots.<locals>.print_hello at 0x7c00d69d0ea0>

# %%
a()
# Out:
# Hello World

# %%
def gen_exp (n) :
  def exp (x) :
    return x ** n
  return exp

# %%
e = gen_exp(5)

e(2)
# Out:
# 32

# %%
def add_num():
  def num(x) :
    return x
  return num

# %%
a = add_num()

# %%
a(5)
# Out:
# 5

# %% [markdown]
# **Without Higher Order Function**

# %%
def expo (x,n):
  return (x**n)

expo(2,5)
# Out:
# 32

# %% [markdown]
# **ASSIGNMENT**

# %% [markdown]
# 1. Write a Python function that takes a string and a length value as input arguments and returns the words from the string whose length is equal to the provided input length value.
# In other words, you will split the string into individual words and then gather only those words that match the specific length given.

# %%
def LengthSequence(string, length) :

  func_inp_list = []
  func_inp_list = string.split()

  result = []

  for i in func_inp_list :

    if len(i) == length :

      result.append(i)

  return result

# %%
inp_str = input("Enter the string : ")
inp_len = int(input("Enter the length : "))

a = LengthSequence(inp_str, inp_len)

print(a)
# Out:
# Enter the string : The world has changed and none of us can go back all we can do is our best and sometimes the best that we can do is to start over
# Enter the length : 5
# ['world', 'start']

# %% [markdown]
# 2. An integer N representing the number of students
# Input of student name and grades for each N student
# Name of Student
# Grade of Student

# %%
def second_lowest(func_stud_list):

  result = sorted(func_stud_list, key = lambda x : x[1], reverse= True)

  for i in range (len(func_stud_list)) :

    if func_stud_list[i][1] != func_stud_list[i+1][1] :
      return (func_stud_list[i+1])

  return(func_stud_list[1])

# %%
total_students = int(input("Enter the total students : "))

main_stud_list = []

for i in range (total_students) :
  stud_list = []
  for j in range (1) :
    name = input("Enter name : ")
    grade = float(input("Enter Grades : "))

    stud_list.append(name)
    stud_list.append(grade)

  main_stud_list.append(stud_list)

out_res = second_lowest(main_stud_list)
print(out_res)
# Out:
# Enter the total students : 4
# Enter name : Sapna
# Enter Grades : 3
# Enter name : Umesh
# Enter Grades : 3
# Enter name : Rahul 2
# Enter Grades : 2
# Enter name : Anil
# Enter Grades : 1
# ['Rahul 2', 2.0]

# %% [markdown]
# You are given a nested list of strings of varying lengths.
#
# For each list, sort the string on the basis of the number of times the character ‘a’ appears in the string such that the string having the most number of ‘a’ comes first in the lists.
#
# Complete the python function and return the sorted list.
#
# Note: If 2 strings has the same number of 'a', keep them in the same order as entered in the list.

# %%
def sort_strings(func_main_list):

  func_num_main_list = []

  for i in range (len(func_main_list)) :

    for j in range (len(func_main_list[i])) :
      func_count_sub_list = []
      count = 0
      for k in range (len(func_main_list[i][j])) :

        if func_main_list[i][j][k] in "Aa" :

          count += 1

      func_count_sub_list.append(count)

    func_num_main_list.append(func_count_sub_list)

  print(func_num_main_list)

# %%
total_lists = int(input("Enter the total number of lists : "))

main_list = []

for i in range (total_lists) :
  total_elements = int(input(f"Enter total elements you want add in sub list {i+1} : "))
  sub_list = []
  for j in range (total_elements) :
    value = input("Enter value : ")

    sub_list.append(value)

  main_list.append(sub_list)

print(main_list)

out_res = sort_strings(main_list)

print(out_res)
# Out:
# Enter the total number of lists : 2
# Enter total elements you want add in sub list 1 : 2
# Enter value : saAaa
# Enter value : sadsaa
# Enter total elements you want add in sub list 2 : 3
# Enter value : asaa
# Enter value : asasa
# Enter value : asasaa
# [['saAaa', 'sadsaa'], ['asaa', 'asasa', 'asasaa']]
# [[3], [4]]
# None
