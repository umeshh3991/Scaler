# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_4/Module_4_Lec_4_sorting2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# merger sort

# %%
def merger(arr1,arr2):
  i = 0 # iteerate over arr1
  j =0 # iterate over arr2

  result = []

  while i< len(arr1) and j< len(arr2):

    if arr1[i]< arr2[j]:
      result.append(arr1[i])
      i +=1

    else:
      result.append(arr2[j])

      j +=1

  if i < len(arr1):
      result += arr1[i:]


  if i < len(arr2):
      result += arr2[j:]

  return(result)

# %%
arr1 =[3,4,5,9,12,44,104,112]
arr2 = [6,8,11,45,90]

print(merger(arr1,arr2))
# Out:
# [3, 4, 5, 6, 8, 9, 11, 12, 44, 45, 90, 104, 112]
