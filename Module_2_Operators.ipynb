# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_2/Module_2_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Types

# %% [markdown]
# 1. Numerical DataTypes

# %%
a = 2+5j
b = 2
c = 7.2

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'complex'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# 2. Boolean Datatype

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
# 3. Derived data type

# %% [markdown]
# i. List

# %%
a = [1,2,3,4.5,5]
print(type(a))
print(a)
# Out:
# <class 'list'>
# [1, 2, 3, 4.5, 5]

# %% [markdown]
# Heterogeneous Example

# %%
a = [5,5.4,5+4j,'umesh',True]
print(type(a))
print(a)
# Out:
# <class 'list'>
# [5, 5.4, (5+4j), 'umesh', True]

# %%
print(a[3])
# Out:
# umesh

# %%
a[4] = "Sapna"
print(a)
# Out:
# [5, 5.4, (5+4j), 'umesh', 'Sapna']

# %% [markdown]
# ii. Tuple

# %%
a = (1,2,3,4.5,5)

print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4.5, 5)

# %% [markdown]
# Heterogeneous Example

# %%
a = (5,5.4,5+4j,'umesh',True)

print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (5, 5.4, (5+4j), 'umesh', True)

# %% [markdown]
# Mapping DataTypes

# %% [markdown]
# 1. Dictionaries

# %%
a = {"prep":"upsc",
     "optional":"math",
     "attempt":6,
     "name":"sapna"
     }

print(a)
# Out:
# {'prep': 'upsc', 'optional': 'math', 'attempt': 6, 'name': 'sapna'}

# %%
a["name"] = "umesh"
print(a)
# Out:
# {'prep': 'upsc', 'optional': 'math', 'attempt': 6, 'name': 'umesh'}

# %% [markdown]
# Homework and Assignments

# %% [markdown]
# 1. Print the result of the following expression:
#
# ```
# (3 + 4) // 2 + 6
# ```

# %%
a = (3+4) // 2+6

print(a)
# Out:
# 9

# %% [markdown]
# Set the value of variable a, b and c such that the following condition evaluates to true:
#
# ```
# a = -1 # change this
# b = -1 # change this
# c = -1 # change this
#
# # DO NOT CHANGE THIS
# x = a < b + c
#
# print(x) # this should be True
# ```

# %%
a = -4 # change this
b = -1 # change this
c = -1 # change this

# DO NOT CHANGE THIS
x = a < b + c

print(x) # this should be True
# Out:
# True

# %% [markdown]
# 3. What is the result of the following expression in Python?
#
# ```
# print("54" + "23")
# ```

# %%
print("54" + "23")
# Out:
# 5423

# %% [markdown]
# 4. What is the result of the following expression in Python?
#
# ```
# print(True == 1)
# ```

# %%
print(True == 1)
# Out:
# True

# %% [markdown]
# 5. What is the result of the following expression in Python?
#
# ```
# print("1" == 1)
# ```

# %%
print("1" == 1)
# Out:
# False

# %% [markdown]
# 6. What is the output for the following statements?
#
# ```
# x = 55 / 11
# print(x)
# ```

# %%
x = 55 / 11
print(x)
# Out:
# 5.0

# %% [markdown]
# 7. Given total bills amount and amount of a single bill. Print number of bills.
#
# Note : The total amount is equally splitted in all bills. The number of bills should be an integer value.

# %%
single_amount_of_bill = int(input("Please Enter Single Bill Amount : " ))
total_bill_amount = int(input("Please Enter Total Bill Amount : "))

Total_No_of_Bill = total_bill_amount // single_amount_of_bill

print(Total_No_of_Bill)
# Out:
# Please Enter Single Bill Amount : 20
# Please Enter Total Bill Amount : 110
# 5

# %% [markdown]
# 8. What is the output of the following code?
#
# ```
# x = 50 * 2 + (60 - 20) / 4
# print(x)
# ```

# %%
x = 50 * 2 + (60 - 20) / 4
print(x)
# Out:
# 110.0

# %% [markdown]
# 9. What is the value of result at the end of the following code?
#
# ```
# x = 20
# y = 5
# result = (x + True) / (4 - y * False)
# ```

# %%
x = 20
y = 5
result = (x + True) / (4 - y * Faalse)

print(result)
# Out:
# 5.25
