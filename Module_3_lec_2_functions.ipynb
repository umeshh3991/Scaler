# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_3/Module_3_lec_2_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10    #global value
def foo ():
  y = 20       ##local value define
  def bar():
    x = 30      ##local value
    print(x)    #give local value
  print(y)      # give loc val
  bar()
  print(x)      #give loc value

foo()
print(x)      #give global value
# Out:
# 20
# 30
# 10
# 10
