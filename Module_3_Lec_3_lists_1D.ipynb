# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_3/Module_3_Lec_3_lists_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(hex(id(a)))   #hexa decimal memory address
# Out:
# 0xa42788

# %%
a =  10
print(id(a))   #memory address
# Out:
# 10758024

# %%
a = 11
b = 11
print(id(a))
print(id(b))
# Out:
# 10758056
# 10758056

# %%
a = 258
b = 258
print(id(a))
print(id(b))
# Out:
# 137488867251888
# 137488867261456

# %%
a = [1,2,3,4]

b = 1
print(id(a))
print(id(b))
# Out:
# 137488864123776
# 10757736

# %%
a = [1,2,3,4]

b = 1
print(id(a[0]))
print(id(b))
# Out:
# 10757736
# 10757736

# %%
a = [1,2,3,4]

b = a
b[0] = 201
print(id(a))
print(id(b))
# Out:
# 137488864373312
# 137488864373312

# %%
a = [1,2,3,4]

b = [3,4]
a = b      # if a= b then not depend what are value of a and b both memory address same
print(id(a))
print(id(b))
# Out:
# 137490200538176
# 137490200538176

# %% [markdown]
# basic operatins list

# %%
a =[1,2,3,4]
len(a)
# Out:
# 4

# %%
a = "scaler"
len(a)
# Out:
# 6

# %%
len([1,2,4] + [3,4,5,7])
# Out:
# 7

# %%
len([a,b]*3)
# Out:
# 6

# %%
len("ab"*7)
# Out:
# 14

# %%
2 in [1,2,5,7,9]
# Out:
# True

# %%
arr = [1,2,5,8,4,9]
for x in arr:
  print(x)
# Out:
# 1
# 2
# 5
# 8
# 4
# 9

# %%
board  = ([[' ']*3] *3)

# %%
board
# Out:
# [[' ', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]

# %%
board[1][1] = 0

# %%
board
# Out:
# [[' ', 0, ' '], [' ', 0, ' '], [' ', 0, ' ']]

# %%
print(id(board[0]))
print(id(board[1]))      ##same memory add becoz all of same ros
print(id(board[2]))
# Out:
# 137488864233856
# 137488864233856
# 137488864233856

# %%
print(id(board[0][1]))
print(id(board[1][2]))
print(id(board[2][0]))
# Out:
# 10757704
# 10800136
# 10800136

# %%
print(id(board[0][0]))
print(id(board[0][1]))
print(id(board[0][2]))
# Out:
# 10800136
# 10757704
# 10800136

# %%
arr =  [1,2,3,4,5]
arr[-1]
# Out:
# 5

# %%
arr[-4]
# Out:
# 2

# %%
arr = list (range(1,9))
print(arr)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
arr[2: 5]
# Out:
# [3, 4, 5]

# %%
arr = list (range(1,9))
arr[::2]
# Out:
# [1, 3, 5, 7]

# %% [markdown]
# check palindrome

# %%
a = "nitin"
a == a[:: -1]
# Out:
# True

# %%
a = "umesh"
a == a[:: -1]
# Out:
# False

# %%
a = "niti"
a[:: -1]
# Out:
# 'itin'

# %%
arr = list (range(0,7))
arr[2:7:1]
arr[::1]
arr[::-1]        #slicing list
# Out:
# [6, 5, 4, 3, 2, 1, 0]

# %%
arr = list (range(1,9))
arr[::2]
# Out:
# [1, 3, 5, 7]

# %%
arr = list (range(1,9))
arr[::-2]
# Out:
# [8, 6, 4, 2]

# %%
def foo(a,b):
  return a**2 , b**2

x,y = foo(5,7)
print(x)
print(y)
# Out:
# 25
# 49

# %%
a = [1,3,5,7,9]
b = a[::2]
print(id(a))
print(id(b))
# Out:
# 137488862778048
# 137488862780224

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'a=5\nprint(hex(id(a)))',
#   'a=4\nprint(hex(id(a)))',
#   'a=4\nprint(hex(id(a)))',
#   'a=10\nprint(hex(id(a)))',
#   'a =  10\nprint(id(a))',
#   'a =  10\nprint(id(a))   #memory address',
#   'a = 11\nb = 11\nprint(id(a))\nprint(id(b))',
#   'a = 258\nb = 258\nprint(id(a))\nprint(id(b))',
#   'a = (1,2,3,4)\n\nb = 1\nprint(id(a))\nprint(id(b))',
#   'a = (1,2,3,4)\n\nb = 1\nprint(id(a[0]))\nprint(id(b))',
#   'a = [1,2,3,4]\n\nb = 1\nprint(id(a))\nprint(id(b))',
#   'a = [1,2,3,4]\n\nb = 1\nprint(id(a[0]))\nprint(id(b))',
#   'a = [1,2,3,4]\n\nb = a\nb[0] = 201\nprint(id(a[0]))\nprint(id(b))',
#   'a = [1,2,3,4]\n\nb = a\nb[0] = 201\nprint(id(a))\nprint(id(b))',
# ...
