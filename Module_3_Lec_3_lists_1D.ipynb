# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_3/Module_3_Lec_3_lists_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(hex(id(a)))   #hexa decimal memory address
# Out:
# 0xa42788

# %%
a =  10
print(id(a))   #memory address
# Out:
# 10758024

# %%
a = 11
b = 11
print(id(a))
print(id(b))
# Out:
# 10758056
# 10758056

# %%
a = 258
b = 258
print(id(a))
print(id(b))
# Out:
# 137488867251888
# 137488867261456

# %%
a = [1,2,3,4]

b = 1
print(id(a))
print(id(b))
# Out:
# 137488864123776
# 10757736

# %%
a = [1,2,3,4]

b = 1
print(id(a[0]))
print(id(b))
# Out:
# 10757736
# 10757736

# %%
a = [1,2,3,4]

b = a
b[0] = 201
print(id(a))
print(id(b))
# Out:
# 137488864373312
# 137488864373312

# %%
a = [1,2,3,4]

b = [3,4]
a = b      # if a= b then not depend what are value of a and b both memory address same
print(id(a))
print(id(b))
# Out:
# 137490200538176
# 137490200538176

# %% [markdown]
# basic operatins list

# %%
a =[1,2,3,4]
len(a)
# Out:
# 4

# %%
a = "scaler"
len(a)
# Out:
# 6

# %%
len([1,2,4] + [3,4,5,7])
# Out:
# 7

# %%
len([a,b]*3)
# Out:
# 6

# %%
(a*3)
# Out:
# 'scalerscalerscaler'

# %%
len("bc"*7)
# Out:
# 14

# %%
("bcd"*7)
# Out:
# 'bcdbcdbcdbcdbcdbcdbcd'

# %%
2 in [1,2,5,7,9]
# Out:
# True

# %%
arr = [1,2,5,8,4,9]
for x in arr:
  print(x)
# Out:
# 1
# 2
# 5
# 8
# 4
# 9

# %%
arr = [1,2,5,8,4,9]
for x in range(len(arr)):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
arr = int(input("enter arr value : "))
for x in range((arr)):
  print(x)
# Out:
# enter arr value : 3
# 0
# 1
# 2

# %%
board  = ([[' ']*3] *3)

# %%
board
# Out:
# [[1, 0, 1], [1, 0, 1], [1, 0, 1]]

# %%
 board[1][1] = 0

# %%
##board[1][1] = 1

# %%
board
# Out:
# [[1, 0, 1], [1, 0, 1], [1, 0, 1]]

# %%
print(id(board[0]))
print(id(board[1]))      ##same memory add becoz all of same ros
print(id(board[2]))
# Out:
# 137488864233856
# 137488864233856
# 137488864233856

# %%
print(id(board[0][1]))
print(id(board[1][2]))
print(id(board[2][0]))
# Out:
# 10757704
# 10800136
# 10800136

# %%
print(id(board[0][0]))
print(id(board[0][1]))
print(id(board[0][2]))
# Out:
# 10800136
# 10757704
# 10800136

# %%
arr =  [1,2,3,4,5]
arr[-1]
# Out:
# 5

# %%
arr[-4]
# Out:
# 2

# %%
arr = list (range(1,9))
print(arr)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
arr[2: 5]
# Out:
# [3, 4, 5]

# %%
arr = list (range(1,9))
arr[::2]
# Out:
# [1, 3, 5, 7]

# %% [markdown]
# check palindrome

# %%
a = "nitin"
a == a[:: -1]
# Out:
# True

# %%
a = "umesh"
a == a[:: -1]
# Out:
# False

# %%
a = "niti"
a[:: -1]
# Out:
# 'itin'

# %%
arr = list (range(0,7))
arr[2:7:1]
arr[::1]
arr[::-1]        #slicing list
# Out:
# [6, 5, 4, 3, 2, 1, 0]

# %%
arr = list (range(1,9))
arr[::2]
# Out:
# [1, 3, 5, 7]

# %%
arr = list (range(1,9))
arr[::-2]
# Out:
# [8, 6, 4, 2]

# %%
def foo(a,b):
  return a**2 , b**2

x,y = foo(5,7)
print(x,y)
# Out:
# 25 49

# %%
a = [1,3,5,7,9]
b = a[::2]
print(id(a))
print(id(b))
# Out:
# 137488862778048
# 137488862780224

# %%
a = 100
def foo():
  a= 200

  def bar():
    a=300

    def baz():
      a=400

      def bae():
        a = 500
        print(a)
      bae()
      print(a)

    baz()
    print(a)

  bar()
  print(a)

foo()
print(a)
# Out:
# 500
# 400
# 300
# 200
# 100

# %%
a = 100
def foo():
  global a

  def bar():
    global a

    def baz():
      a=400

      def bae():

        print(a)
      bae()
      print(a)

    baz()
    print(a)

  bar()
  print(a)

foo()
print(a)
# Out:
# 400
# 400
# 100
# 100
# 100

# %%
a = 100
def foo():
  global a

  def bar():
    a = 200

  print(a)
  bar()
  print(a)

foo()
print(a)
# Out:
# 100
# 100
# 100

# %%
a = 100
def foo():
  global a

  def bar():
    a = 300

    def baz():
      nonlocal a

      def bae():

        print(a)
      bae()
      print(a)

    baz()
    print(a)

  bar()
  print(a)

foo()
print(a)
# Out:
# 300
# 300
# 300
# 100
# 100

# %%
A = []

for i in range(1,9):
  A.append(i**2)

print(A)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %% [markdown]
# list comprehensipn example.

# %%
A = [i**2 for i in range(1,9)]
print(A)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
n = 5
[[max(i+1,j+1,n-i,n-j) for j in range(n)]for i in range(n)]
# Out:
# [[5, 5, 5, 5, 5],
#  [5, 4, 4, 4, 5],
#  [5, 4, 3, 4, 5],
#  [5, 4, 4, 4, 5],
#  [5, 5, 5, 5, 5]]

# %%
n = 5
print("\n".join (["  ".join([str(max(i+1,j+1,n-i,n-j)) for j in range(n)])for i in range(n)]))
# Out:
# 5  5  5  5  5
# 5  4  4  4  5
# 5  4  3  4  5
# 5  4  4  4  5
# 5  5  5  5  5

# %%
n = 5
print ([" ".join([str(max(i+1,j+1,n-i,n-j)) for j in range(n)])for i in range(n)])
# Out:
# ['5 5 5 5 5', '5 4 4 4 5', '5 4 3 4 5', '5 4 4 4 5', '5 5 5 5 5']

# %%
n = 5
print ("".join([" ".join([str(max(i+1,j+1,n-i,n-j)) for j in range(n)])for i in range(n)]))
# Out:
# 5 5 5 5 55 4 4 4 55 4 3 4 55 4 4 4 55 5 5 5 5

# %%
n = 5
print ("\n\n".join(["  ".join([str(max(i+1,j+1,n-i,n-j)) for j in range(n)])for i in range(n)]))
# Out:
# 5  5  5  5  5
#
# 5  4  4  4  5
#
# 5  4  3  4  5
#
# 5  4  4  4  5
#
# 5  5  5  5  5

# %%
a = [1,3,3,4,5]

n = len(a)
for i in range(n-1):
  if (a[i] == a[i+1]):
    print("true")
    break

else:
    print("false")
# Out:
# true

# %% [markdown]
# Problem Description
#
# Write a program to find the difference between the sum of all even elements and the sum of all odd elements from the given array, A.
# Note: The array of elements will be passed as an argument to the function. You don't need to take any input of array.
#
# Problem Constraints
#
# 1 <= len(A) <= 105
# 1 <= A[i] <= 105
#
#
# Input Format
#
# The only argument is the array of integers, A.
#
#
# Output Format
#
# The difference of the even and odd elements sum in integer format.
#
#
# Example Input
#
# Input 1:
#
# 56 63 87 24 32 13 15 19 44 52
# Input 2:
#
# 2 8 4 6
#
# Example Output
#
# Output 1:
# 11
# Output 2:
# 20

# %%
def difference(n):
  sum1 = 0
  sum2 = 0

  for i in  (n):

    if (i % 2 ) == 0:
      sum1 = sum1 + i

    else:
      sum2 = sum2 + i

  difference = (sum1 - sum2)

  if difference < 0:
    difference = difference *(-1)

  return(difference)

# %%
A = []
N = int(input("Enter number of element N : "))

for i in range(N):
  element = int(input("Enter all elemments of array : "))
  A.append(element)

Y = difference(A)

print(Y)
print(A)
# Out:
# Enter number of element N : 7
# Enter all elemments of array : 1
# Enter all elemments of array : 5
# Enter all elemments of array : 7
# Enter all elemments of array : 6
# Enter all elemments of array : 78
# Enter all elemments of array : 12
# Enter all elemments of array : 36
# 119
# [1, 5, 7, 6, 78, 12, 36]

# %% [markdown]
# 2. Problem Description
#
# Write a program to print sum of elements of the input array A of size N.
#
# Note: User is supposed to write a program from scratch to add the elements of the input array and print the result.
#
#
# Problem Constraints
#
#
# 1 <= N <= 1000
#
# 1 <= A <= 1000
#
#
#
#
# Input Format
#
# - The first integer N denotes the number of integers in the array.
# - The next N integers denotes the element of the array A.
#
#
#
# Output Format
#
# A single integer containing sum of elements from the input array.
#
#
#
#
# Example Input
#
#
# Input 1:
#
#
# 5 1 2 3 4 5
# Input 2:
#
# 4 10 50 40 80
#
#
#
# Example Output
#
# Output 1:
#
# 15
# Output 2:

# %%
def sum(n):

  sum = 0

  for i in (n):
    sum = sum + i

  return(sum)

# %%
A = []
N = int(input("Enter number of element N : "))

for i in range(N):
  element = int(input("Enter all elemments of array : "))
  A.append(element)

Y = sum(A)

print(Y)
# Out:
# Enter number of element N : 4
# Enter all elemments of array : 1
# Enter all elemments of array : 2
# Enter all elemments of array : 3
# Enter all elemments of array : 4
# 10

# %% [markdown]
# 3. Problem Description
#
# Write a function to check if the given array A has consecutive duplicate elements or not.
# Return True if there are consecutive duplicate elements in the list else return False.
#
# Here by consecutive duplicates, we mean duplicates that are present at consecutive indices in the array
#
#
# Problem Constraints
#
# 1 <= N <= 105
# 1 <= A[i] <= 109
#
#
# Input Format
#
# An integer array A as the function argument.
#
#
# Output Format
#
# Return True or False
#
#
# Example Input
#
# Input 1:
# 1
# 4
# 1 2 3 3
# Input 2:
# 1
# 2
# 1 2
#
#
# Example Output
#
# Output 1:
# True
# Output 2:
# False

# %%
def consecutive_duplicate(n):

  i = 1
  #print(len(n))


  while (i < (len(n))) :



    if  (n[i] == n[i-1]):
      return(True)
    i += 1

  else:
    return(False)

# %%
def consecutive_duplicate(n):
  for i in range(len(n)-1):
    if  (n[i] == n[i+1]):

      return(True)



  return(False)

# %%
A = []
N = int(input("Enter number of element N : "))

for i in range(N):
  element = int(input("Enter all elemments of array : "))


  A.append(element)

Y = consecutive_duplicate(A)

print(Y)
# Out:
# Enter number of element N : 5
# Enter all elemments of array : 1
# Enter all elemments of array : 2
# Enter all elemments of array : 3
# Enter all elemments of array : 4
# Enter all elemments of array : 2
# False

# %% [markdown]
# 4. Problem Description
#
# Write a program for a given integer x and a list ls to return the first multiple of x that occurs in the list,
# and if there isn’t any multiple of x in the list then return -1.
#
# Note: The list with elements and the integer x is already passed as an argument to the function. User don't need to take any input. Just perform the task on the passed arguments and return the required result.
#
# Problem Constraints
#
# 1 <= len(ls) <= 103
# 1 <= ls[i] <= 105
# 1 <= x <= 105
#
#
# Input Format
#
# First line of input is number of test cases t.
# The remaining lines contain the test cases.
# For each test case-
# First line of input is the integer x.
# Second line of input contains the elements of ls, separated by spaces.
#
#
# Output Format
#
# Return the first multiple of x from the list in integer format, else return -1.
#
#
# Example Input
#
# Input 1:
# ls = [2, 1, 2, 4, 3, 5]
# x  = 4
# Input 2:
# ls = [7, 5, 3, 17]
# x  = 2
#
#
# Example Output
#
# Output 1:
# 4
# Output 2:
# -1

# %%
def first_multiple(n,x):

  for  i in range (len(n)):

    if (n[i] % x == 0):
      return(n[i])



  return(-1)

# %%
A = []
N = int(input("Enter number of element N : "))
X = int(input("Enter  X : "))

for i in range (N):
  element = int(input("Enter all elemments of array : "))
  A.append(element)

Y = first_multiple(A,X)

print(Y)
# Out:
# Enter number of element N : 5
# Enter  X : 2
# Enter all elemments of array : 1
# Enter all elemments of array : 3
# Enter all elemments of array : 5
# Enter all elemments of array : 7
# Enter all elemments of array : 4
# 4
