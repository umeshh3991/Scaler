# %% [markdown]
# <a href="https://colab.research.google.com/github/umeshh3991/Scaler/blob/Sapna_Module_4/Mod_4_Lec_1_Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = [ i**2 for i in range (1,11)]

# %%
arr
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
arr = { i**2 for i in range (1,11)}

# %%
arr
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
arr = {i: i**2 for i in range (1,11)}

# %%
arr
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
arr = ( i**2 for i in range (1,11))
print(arr)                            #its gen not tuple
print(type(arr))
# Out:
# <generator object <genexpr> at 0x7abbd68769b0>
# <class 'generator'>

# %% [markdown]
# iteration protocol in python

# %%
arr = [1,2,3]
a = iter(arr)

# %%
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 2

# %%
next(a)
# Out:
# 3

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-17-1242322984.py in <cell line: 0>()
# ----> 1 next(a)
#
# StopIteration:
